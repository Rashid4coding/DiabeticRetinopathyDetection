# %% [markdown]
# # Setup

# %%
import numpy as np
import os
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, \
                    classification_report, confusion_matrix
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE

import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, ReLU, \
                                        Lambda, GlobalAveragePooling2D, Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications import ResNet50,ResNet101,ResNet152
from tensorflow.keras.applications.resnet50 import preprocess_input
from keras.preprocessing import image
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras import layers, Model, optimizers


from tqdm.auto import tqdm

from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from collections import Counter

import pickle

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %%
os.chdir("/content/drive/MyDrive/DiabeticRetinopathyDetection")

# %% [markdown]
# # Hyperprameters

# %%
IMAGE_SIZE = 150
BASE_MODEL = ResNet101(weights='imagenet', include_top=False, input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet101_weights_tf_dim_ordering_tf_kernels_notop.h5
# 171446536/171446536 [==============================] - 9s 0us/step

# %% [markdown]
# # Loading features

# %%
labeled_data_features = np.load("data/processed/train/features/labeled_data_features.npy")
print("Loaded features", labeled_data_features.shape)
# Out:
# Loaded features (35122, 51200)

# %%
labeled_data = pd.read_csv("data/ext/trainlabels.csv")

labeled_data_labels = labeled_data['level']

print("labeled data labels", len(labeled_data_labels))
print("Class distribution before balancing:", Counter(labeled_data_labels))
# Out:
# labeled data labels 35122
# Class distribution before balancing: Counter({0: 25808, 2: 5291, 1: 2442, 3: 873, 4: 708})

# %% [markdown]
# # Data Split

# %%
undersampled_features = labeled_data_features
undersampled_labels = labeled_data_labels

print("Class distribution after balancing:", Counter(undersampled_labels))
print("Shape of oversampled features:", undersampled_labels.shape)
print("Shape of oversampled labels:", undersampled_labels.shape)
# Out:
# Class distribution after balancing: Counter({0: 25808, 2: 5291, 1: 2442, 3: 873, 4: 708})
# Shape of oversampled features: (35122,)
# Shape of oversampled labels: (35122,)

# %%
X_train, X_val, y_train, y_val = train_test_split(
    undersampled_features, undersampled_labels,
    stratify=undersampled_labels,
    test_size=0.2, random_state=42
)

# %% [markdown]
# # Model Training on labeled data

# %%
y_train = to_categorical(y_train)
y_val = to_categorical(y_val)

# %%
classifier = Sequential([
    Dense(1024, input_shape=(X_train.shape[1],)),
    BatchNormalization(),
    Dropout(0.2),
    ReLU(),

    Dense(512),
    BatchNormalization(),
    Dropout(0.2),
    ReLU(),

    Dense(256),
    BatchNormalization(),
    Dropout(0.2),
    ReLU(),

    Dense(5, activation='softmax')
])

classifier.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

history = classifier.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val))
# Out:
# Epoch 1/50
# 879/879 [==============================] - 26s 24ms/step - loss: 0.8669 - accuracy: 0.7214 - val_loss: 0.7845 - val_accuracy: 0.7382
# Epoch 2/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.7717 - accuracy: 0.7432 - val_loss: 0.7608 - val_accuracy: 0.7482
# Epoch 3/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.7249 - accuracy: 0.7506 - val_loss: 0.7887 - val_accuracy: 0.7428
# Epoch 4/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.6819 - accuracy: 0.7617 - val_loss: 0.8252 - val_accuracy: 0.7095
# Epoch 5/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.6295 - accuracy: 0.7751 - val_loss: 0.8159 - val_accuracy: 0.7432
# Epoch 6/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.5705 - accuracy: 0.7923 - val_loss: 0.8956 - val_accuracy: 0.7409
# Epoch 7/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.5040 - accuracy: 0.8141 - val_loss: 0.8979 - val_accuracy: 0.7250
# Epoch 8/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.4397 - accuracy: 0.8371 - val_loss: 0.9920 - val_accuracy: 0.7167
# Epoch 9/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.3804 - accuracy: 0.8582 - val_loss: 1.1025 - val_accuracy: 0.7367
# Epoch 10/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.3259 - accuracy: 0.8780 - val_loss: 1.1041 - val_accuracy: 0.7223
# Epoch 11/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.2796 - accuracy: 0.8955 - val_loss: 1.1505 - val_accuracy: 0.6928
# Epoch 12/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.2452 - accuracy: 0.9071 - val_loss: 1.2410 - val_accuracy: 0.6776
# Epoch 13/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.2193 - accuracy: 0.9168 - val_loss: 1.3823 - val_accuracy: 0.6289
# Epoch 14/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.1988 - accuracy: 0.9279 - val_loss: 1.5511 - val_accuracy: 0.6974
# Epoch 15/50
# 879/879 [==============================] - 19s 21ms/step - loss: 0.1743 - accuracy: 0.9347 - val_loss: 1.5033 - val_accuracy: 0.6611
# Epoch 16/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.1615 - accuracy: 0.9401 - val_loss: 1.5659 - val_accuracy: 0.7090
# Epoch 17/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.1468 - accuracy: 0.9450 - val_loss: 1.6040 - val_accuracy: 0.6685
# Epoch 18/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.1345 - accuracy: 0.9506 - val_loss: 1.7885 - val_accuracy: 0.7110
# Epoch 19/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.1264 - accuracy: 0.9534 - val_loss: 1.6207 - val_accuracy: 0.6865
# Epoch 20/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.1218 - accuracy: 0.9556 - val_loss: 1.5799 - val_accuracy: 0.6621
# Epoch 21/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.1112 - accuracy: 0.9597 - val_loss: 1.9523 - val_accuracy: 0.7201
# Epoch 22/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.1054 - accuracy: 0.9608 - val_loss: 1.8119 - val_accuracy: 0.6562
# Epoch 23/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0984 - accuracy: 0.9644 - val_loss: 2.0333 - val_accuracy: 0.7174
# Epoch 24/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0882 - accuracy: 0.9683 - val_loss: 2.1028 - val_accuracy: 0.7018
# Epoch 25/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0940 - accuracy: 0.9656 - val_loss: 1.9186 - val_accuracy: 0.6964
# Epoch 26/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0814 - accuracy: 0.9696 - val_loss: 1.9307 - val_accuracy: 0.7051
# Epoch 27/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0790 - accuracy: 0.9722 - val_loss: 1.9440 - val_accuracy: 0.6932
# Epoch 28/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0805 - accuracy: 0.9716 - val_loss: 2.0207 - val_accuracy: 0.6928
# Epoch 29/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0747 - accuracy: 0.9731 - val_loss: 2.1249 - val_accuracy: 0.7189
# Epoch 30/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0702 - accuracy: 0.9745 - val_loss: 1.9177 - val_accuracy: 0.6797
# Epoch 31/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0683 - accuracy: 0.9753 - val_loss: 2.1206 - val_accuracy: 0.6861
# Epoch 32/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0670 - accuracy: 0.9763 - val_loss: 2.3188 - val_accuracy: 0.7287
# Epoch 33/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0625 - accuracy: 0.9790 - val_loss: 2.0577 - val_accuracy: 0.6957
# Epoch 34/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0571 - accuracy: 0.9800 - val_loss: 2.1266 - val_accuracy: 0.6908
# Epoch 35/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0655 - accuracy: 0.9767 - val_loss: 2.1421 - val_accuracy: 0.7048
# Epoch 36/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0592 - accuracy: 0.9794 - val_loss: 2.1696 - val_accuracy: 0.6958
# Epoch 37/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0583 - accuracy: 0.9801 - val_loss: 2.0479 - val_accuracy: 0.6912
# Epoch 38/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0581 - accuracy: 0.9795 - val_loss: 2.2528 - val_accuracy: 0.7056
# Epoch 39/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0504 - accuracy: 0.9816 - val_loss: 2.3829 - val_accuracy: 0.7095
# Epoch 40/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0568 - accuracy: 0.9811 - val_loss: 2.3749 - val_accuracy: 0.7053
# Epoch 41/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0503 - accuracy: 0.9821 - val_loss: 2.3652 - val_accuracy: 0.6920
# Epoch 42/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0530 - accuracy: 0.9821 - val_loss: 2.3754 - val_accuracy: 0.7042
# Epoch 43/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0445 - accuracy: 0.9841 - val_loss: 2.4084 - val_accuracy: 0.7046
# Epoch 44/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0503 - accuracy: 0.9828 - val_loss: 2.6034 - val_accuracy: 0.7293
# Epoch 45/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0486 - accuracy: 0.9833 - val_loss: 2.2923 - val_accuracy: 0.6874
# Epoch 46/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0481 - accuracy: 0.9836 - val_loss: 2.2156 - val_accuracy: 0.6883
# Epoch 47/50
# 879/879 [==============================] - 18s 21ms/step - loss: 0.0443 - accuracy: 0.9846 - val_loss: 2.1680 - val_accuracy: 0.6793
# Epoch 48/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0468 - accuracy: 0.9838 - val_loss: 2.3583 - val_accuracy: 0.7053
# Epoch 49/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0420 - accuracy: 0.9854 - val_loss: 2.3014 - val_accuracy: 0.6908
# Epoch 50/50
# 879/879 [==============================] - 18s 20ms/step - loss: 0.0412 - accuracy: 0.9855 - val_loss: 2.7919 - val_accuracy: 0.7260

# %%
r = pd.DataFrame(history.history)
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].plot(r.index, r['loss'], label='Train loss')
ax[0].plot(r.index, r['val_loss'], label='Validation loss')
ax[1].plot(r.index, r['accuracy'], label='Train accuracy')
ax[1].plot(r.index, r['val_accuracy'], label='Validation accuracy')
ax[0].legend()
ax[1].legend()
plt.show()

# %%
np.save(f"data/experiments/experiment4/X_train.npy", X_train)
np.save(f"data/experiments/experiment4/y_train.npy", y_train)

np.save(f"data/experiments/experiment4/X_val.npy", X_val)
np.save(f"data/experiments/experiment4/y_val.npy", y_val)

classifier.save(f"data/experiments/experiment4/classifier.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# # KNN Model training

# %%
X_train = np.load(f"data/experiments/experiment4/X_train.npy")
y_train = np.load(f"data/experiments/experiment4/y_train.npy")

X_val = np.load(f"data/experiments/experiment4/X_val.npy")
y_val = np.load(f"data/experiments/experiment4/y_val.npy")

# %%
y_train_straight = np.argmax(y_train, axis=1)
y_val_straight = np.argmax(y_val, axis=1)

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train_straight)

print(f"Training Accuracy: {knn.score(X_train, y_train_straight)})")
print(f"Validation Accuracy: {knn.score(X_val, y_val_straight)})")
# Out:
# Training Accuracy: 0.7585863259422714)
# Validation Accuracy: 0.7201423487544484)

# %%
pickle.dump(knn, open('data/experiments/experiment4/knn.sav', 'wb'))

# %% [markdown]
# # Evaluating on Validation set

# %%
X_train = np.load(f"data/experiments/experiment4/X_train.npy")
y_train = np.load(f"data/experiments/experiment4/y_train.npy")

X_val = np.load(f"data/experiments/experiment4/X_val.npy")
y_val = np.load(f"data/experiments/experiment4/y_val.npy")

classifier = tf.keras.models.load_model(f"data/experiments/experiment4/classifier.h5")
knn = pickle.load(open('data/experiments/experiment4/knn.sav', 'rb'))

# %% [markdown]
# ## Classifier

# %%
train_loss, train_acc = classifier.evaluate(X_train, y_train)
val_loss, val_acc = classifier.evaluate(X_val, y_val)

print('Training Accuracy:', train_acc)
print('Validation Accuracy:', val_acc)
# Out:
# 879/879 [==============================] - 29s 32ms/step - loss: 0.0273 - accuracy: 0.9899
# 220/220 [==============================] - 7s 32ms/step - loss: 2.7919 - accuracy: 0.7260
# Training Accuracy: 0.9898565411567688
# Validation Accuracy: 0.725978672504425

# %% [markdown]
# ## KNN

# %%
y_train_straight = np.argmax(y_train, axis=1)
y_val_straight = np.argmax(y_val, axis=1)

# %%
print(f"Training Accuracy: {knn.score(X_train, y_train_straight)})")
print(f"Validation Accuracy: {knn.score(X_val, y_val_straight)})")
# Out:
# Training Accuracy: 0.7585863259422714)
# Validation Accuracy: 0.7201423487544484)

# %% [markdown]
# ## Combined

# %%
def combine_predictions(samples, classifier_weight=0.95):

  classifier = tf.keras.models.load_model(f"data/experiments/experiment4/classifier.h5")
  knn = pickle.load(open('data/experiments/experiment4/knn.sav', 'rb'))

  classifier_pred_proba = classifier.predict(samples)
  knn_pred_proba = knn.predict_proba(samples)

  # Combine predictions with weighted sum
  pred = (classifier_weight * classifier_pred_proba) + ((1 - classifier_weight) * knn_pred_proba)

  # Choose the class with the highest combined probability
  pred = np.argmax(pred, axis=1)

  return pred

# %%
y_pred = combine_predictions(X_val)
# Out:
# 220/220 [==============================] - 7s 32ms/step

# %%
# Calculate precision, recall, and F1 score
accuracy = accuracy_score(y_val_straight, y_pred)
precision = precision_score(y_val_straight, y_pred, average='weighted')
recall = recall_score(y_val_straight, y_pred, average='weighted')
f1 = f1_score(y_val_straight, y_pred, average='weighted')

# Print the results
print('Accuracy:', accuracy)
print('Precision:', precision)
print('Recall:', recall)
print('F1 score:', f1)
# Out:
# Accuracy: 0.7262633451957295
# Precision: 0.6558766661528954
# Recall: 0.7262633451957295
# F1 score: 0.6758157487735245

# %%
# Confusion Matrix

cm = confusion_matrix(y_val_straight, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()

# %%
print(classification_report(y_val_straight, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85      5162
#            1       0.12      0.04      0.06       488
#            2       0.40      0.16      0.22      1058
#            3       0.25      0.17      0.20       175
#            4       0.47      0.42      0.44       142
#
#     accuracy                           0.73      7025
#    macro avg       0.40      0.34      0.36      7025
# weighted avg       0.66      0.73      0.68      7025
